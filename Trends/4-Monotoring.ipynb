# %% [markdown]
# ### Monotoring
# 1. Iterative Improvement

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from wordcloud import WordCloud, STOPWORDS
from IPython.display import Image
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv("Datasets/shopping_trends_updated.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter           3.10                 Yes
# 1          Maine    L     Maroon  Winter           3.10                 Yes
# 2  Massachusetts    S     Maroon  Spring           3.10                 Yes
# 3   Rhode Island    M     Maroon  Spring           3.50                 Yes
# 4         Oregon    M  Turquoise  Spring           2.70                 Yes
#
# ...

# %% [markdown]
# 1. Set Up Logging and Alerting System::
# - Use logging libraries in your Python script to record important events, errors, and performance metrics.
# - Log entries can be stored locally or in a centralized logging system.

# %%
import logging
from datetime import datetime


# Configure logging
logging.basicConfig(filename='Results/model_logs.log', level=logging.INFO)

# Example usage
# Example usage with timestamp
current_timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
logging.info(f"{current_timestamp}::::Model started successfully.")

# %% [markdown]
# 2. Track Key Metrics:
# - Define and track key performance metrics that are relevant to your model's objectives.
# - Use a monitoring tool or dashboard to visualize these metrics over time.

# %%
import time

# Example continuous monitoring loop
flag=True
while flag:
    # Model predictions and evaluation 
    import json
    with open('Results/classification_results.json', 'r') as json_file:
        loaded_results_dict = json.load(json_file)

    # Log key metrics
    current_timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    logging.info(f"{current_timestamp}::::F1 Score: {loaded_results_dict['F1 Score'] :.2f}%")
    logging.info(f"{current_timestamp}::::Accuracy: {loaded_results_dict['Accuracy'] :.2f}%")

    # Sleep for a specific interval (e.g., every 15 seconds)
    #time.sleep(15)
    flag=False #this is just a test so dont need to be running monitoring the model

# %% [markdown]
# 3. Use Cloud Monitoring Services:
# - Leverage cloud platform-specific monitoring services (e.g., AWS CloudWatch, Google Cloud Monitoring) for real-time insights into resource usage, errors, and other relevant metrics.
# - Set up alerts for critical events.

# %% [markdown]
# 4. Implement Health Checks:
# - Regularly check the health of your model by implementing health checks that verify its responsiveness and correctness.

# %%
def model_health_check():
    # Implement checks for model responsiveness and correctness
    #check metrics results
    # for example acc droped from 78% to 68%, return flag
    


    # Log the results
    logging.info("Model health check passed.")

# Example usage
model_health_check()

# %% [markdown]
# 5. Visualize Metrics Locally:
# - Use Python libraries for data visualization (e.g., Matplotlib, Plotly) to create local dashboards displaying key metrics.

# %%
import matplotlib.pyplot as plt

# Example visualization
def plot_metrics(metrics_dict):
    # Create plots based on the metrics_dict
    
    # Save or display the plots
    pass

# Example usage
# Retrieve metrics from logs or monitoring system
metrics_dict = {'timestamp': [...], 'mean_percentage_error': [...]}

# Plot the metrics
plot_metrics(loaded_results_dict)

# %% [markdown]
# 6. Data drift
#
# - Monitoring data drift involves tracking changes in the distribution or characteristics of the input data over time.
#
# 7. Documentation:
# - Maintain thorough documentation for your monitoring and logging procedures to facilitate collaboration and troubleshooting.
# 8. Continuous Improvement:
# - Regularly review monitoring data and logs to identify areas for improvement in your model or deployment infrastructure.
